# %% [markdown]
# # Exploracion temperatura media

# %%
import os

import matplotlib.pyplot as plt
import pandas as pd

from IPython.display import display, HTML

directory = os.path.dirname(os.getcwd())
data_path = os.path.join(directory, "data")
file_path = os.path.join(data_path, "cr2_tasAmon_2018_ghcn/cr2_tasAmon_2018_ghcn.txt")

raw = pd.read_table(file_path, sep=",", index_col=0, na_values=[-9999, "-"],
                    low_memory=False)
table = raw.transpose()
groups = table.columns.to_series().groupby(table.dtypes).groups

table[table.columns.values[14:]] = table[table.columns.values[14:]].apply(pd.to_numeric)
table[['codigo_estacion', 'latitud', 'longitud', 'codigo_cuenca', 'codigo_sub_cuenca', 'cantidad_observaciones']] = table[
    ['altura', 'latitud', 'longitud', 'codigo_cuenca', 'codigo_sub_cuenca', 'cantidad_observaciones']].apply(
    pd.to_numeric)
table[['inicio_observaciones', 'fin_observaciones', 'inicio_automatica']] = \
    table[['inicio_observaciones', 'fin_observaciones', 'inicio_automatica']].apply(pd.to_datetime)

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)


display(table)
c = table['1995-07']
#list(c.index)

cc = pd.DataFrame({'loc': c.index, 'value': c.values}).set_index('loc')

#display(cc)

ccc = cc.loc[cc['value'].idxmax()]
display(ccc)

ax = c.plot.hist(use_index=True)
plt.text(0.75, 0.95, f"nulls = {c.isnull().sum()}", transform=ax.transAxes, fontsize=14,
          verticalalignment='top')
plt.show()

k = table[table.columns.values[14:]].isnull().sum()
k.index.name = 'meses'

def trycatch(x):
    try:
        return pd.Period(x)
    except:
        print(x)

k = k.drop(k.index[-1])
#print("Dataframe k:")
#display(k)

k.index = k.index.map(lambda x: pd.Period(x))

dates = k.index.values
ts = pd.DataFrame({'date': dates,
                   'nulls': k.values}).set_index('date')
ax1 = ts.plot()
plt.text(0.5, 0.9, f"total de estaciones= {k.size}", transform=ax.transAxes, fontsize=14,
         verticalalignment='top')
ax1.set_ylabel("cantidad de estaciones con datos nulls")

plt.show()


def region(lat, lng):
    if lat > -27.6307621:
        return 0  # "Norte Grande"
    if lat > -32.759362:
        return 1  # "Norte Chico"
    if lat > -38.0613847:
        return 2  # "Central"
    if lat > -43.7890687:
        return 3  # "Sur"
    if lat > -56:
        return 4  # "Austral"
    else:
        return 5  # "Antartica"


def str_region(n):
    if n == 0:
        return "Norte Grande"
    if n == 1:
        return "Norte Chico"
    if n == 2:
        return "Central"
    if n == 3:
        return "Sur"
    if n == 4:
        return "Austral"
    else:
        return "Antartica"


zona = table[['latitud', 'longitud']].apply(lambda x: region(x['latitud'], x['longitud']), axis=1)
table['zona'] = zona

gb = table[table.columns.values[14:]].groupby(['zona'], axis=0)
final = gb.apply(lambda x: x[14:].mean())
final.index = final['zona']
final = final.drop(['zona'], axis=1)

final = final.drop('codigo_estacion', 1)
print("Dataframe final:")
display(final)

final.columns = final.columns.map(lambda x: trycatch(x))

for i, row in final.iterrows():
    axn = row.plot()
    plt.title(str_region(i))
    plt.xlabel("tiempo")
    plt.ylabel("promedio de temperatura (mm)")
    plt.show()

# %%
import os

import matplotlib.pyplot as plt
import pandas as pd

from IPython.display import display, HTML



def decada(data):
    if(data[:2] == '19' or data[:2] == '20'):
        return data[:3] + '0s'
    return data
    
    

directory = os.path.dirname(os.getcwd())
data_path = os.path.join(directory, "data")
file_path = os.path.join(data_path, "cr2_tasAmon_2018_ghcn/cr2_tasAmon_2018_ghcn.txt")

raw = pd.read_table(file_path, sep=",", index_col=0, na_values=[-9999, "-"],
                    low_memory=False)
table = raw.transpose()
groups = table.columns.to_series().groupby(table.dtypes).groups

table[table.columns.values[14:]] = table[table.columns.values[14:]].apply(pd.to_numeric)
table[['codigo_estacion', 'latitud', 'longitud', 'codigo_cuenca', 'codigo_sub_cuenca', 'cantidad_observaciones']] = table[
table[['inicio_observaciones', 'fin_observaciones', 'inicio_automatica']] = \
    table[['inicio_observaciones', 'fin_observaciones', 'inicio_automatica']].apply(pd.to_datetime)

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)



#display(table[14:])

#obtener nombres de las columnas
columnHeaders = list(table)

#Transformar los años en decadas
columnDecades = list()
for x in columnHeaders:
    columnDecades.append((lambda x:decada(x))(x))

#decadas
listaDecadas = ['1900s', '1910s', '1920s', '1930s', '1940s', '1950s', 
          '1960s', '1970s', '1980s', '1990s', '2000s', '2010s']
listaColumnas = ['institucion', 'fuente', 'nombre', 'altura', 
                'latitud' , 'longitud', 'codigo_cuenca' , 'nombre_cuenca',
                'codigo_sub_cuenca', 'nombre_sub_cuenca']
# columnDecades.pop()
# columnDecades = list('codigo_estacion') + columnDecades
#display(columnDecades)
columnDecades[-1] = 'registros_totales'

#asignar nuevas columnas
table2 = table
table2.columns = columnDecades
#botar ultima columna
#table2 = table2.drop(labels='registros_totales', axis=1)
#display(table2)

# agrupar por columna decada
auxgb = table2[listaDecadas].groupby(level=0, axis=1).mean()
auxconcat = table2[listaColumnas]
frames = [auxconcat, auxgb]
dataResult = pd.concat(frames)
table2 = dataResult

#display(table2)

#sumar numero de datos nulos por decada
nandata = table2['1910s'].isnull().sum()
print(nandata)


# agrupar por zona
# def region(lat, lng):
#     if lat > -27.6307621:
#         return 0  # "Norte Grande"
#     if lat > -32.759362:
#         return 1  # "Norte Chico"
#     if lat > -38.0613847:
#         return 2  # "Central"
#     if lat > -43.7890687:
#         return 3  # "Sur"
#     if lat > -56:
#         return 4  # "Austral"
#     else:
#         return 5  # "Antartica"


# def str_region(n):
#     if n == 0:
#         return "Norte Grande"
#     if n == 1:
#         return "Norte Chico"
#     if n == 2:
#         return "Central"
#     if n == 3:
#         return "Sur"
#     if n == 4:
#         return "Austral"
#     else:
#         return "Antartica"


# zona = table2[['latitud', 'longitud']].apply(lambda x: region(x['latitud'], x['longitud']), axis=1)
# table2['zona'] = zona
# gb = table2[listaDecadas].groupby(zona, axis=0).mean()
# display(gb)

# final = gb.apply(lambda x: x[listaDecadas].mean())
# final.index = final['zona']
# final = final.drop(['zona'], axis=1)
# display(final)

# %%
import os

import matplotlib.pyplot as plt
import pandas as pd

from IPython.display import display, HTML



def decada(data):
    if(data[:2] == '19' or data[:2] == '20'):
        return data[:3] + '0s'
    return data
    
    

directory = os.path.dirname(os.getcwd())
data_path = os.path.join(directory, "data")
file_path = os.path.join(data_path, "cr2_tasAmon_2018_ghcn/cr2_tasAmon_2018_ghcn.txt")

raw = pd.read_table(file_path, sep=",", index_col=0, na_values=[-9999, "-"],
                    low_memory=False)
table = raw.transpose()
groups = table.columns.to_series().groupby(table.dtypes).groups

table[table.columns.values[14:]] = table[table.columns.values[14:]].apply(pd.to_numeric)
table[['codigo_estacion', 'latitud', 'longitud', 'codigo_cuenca', 'codigo_sub_cuenca', 'cantidad_observaciones']] = table[
    ['altura', 'latitud', 'longitud', 'codigo_cuenca', 'codigo_sub_cuenca', 'cantidad_observaciones']].apply(
    pd.to_numeric)
table[['inicio_observaciones', 'fin_observaciones', 'inicio_automatica']] = \
    table[['inicio_observaciones', 'fin_observaciones', 'inicio_automatica']].apply(pd.to_datetime)

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

def region(lat, lng):
    if lat > -27.6307621:
        return 0  # "Norte Grande"
    if lat > -32.759362:
        return 1  # "Norte Chico"
    if lat > -38.0613847:
        return 2  # "Central"
    if lat > -43.7890687:
        return 3  # "Sur"
    if lat > -56:
        return 4  # "Austral"
    else:
        return 5  # "Antartica"


def str_region(n):
    if n == 0:
        return "Norte Grande"
    if n == 1:
        return "Norte Chico"
    if n == 2:
        return "Central"
    if n == 3:
        return "Sur"
    if n == 4:
        return "Austral"
    else:
        return "Antartica"


zona = table[['latitud', 'longitud']].apply(lambda x: region(x['latitud'], x['longitud']), axis=1)

table['zona'] = zona

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

#nunero de localidades
locnum = table.shape[0] #889
#rango de temperaturas
maxTempDf = table.select_dtypes(include=[np.number]).max()
maxtemp = np.nanmax(list(maxTempDf)[5:1422]) #37.755

minTempDf = table.select_dtypes(include=[np.number]).min()
mintemp = np.nanmin(list(minTempDf)[5:1422]) #-75.395

#lista de nombres, si es nulo se pone su codigo
#indice columna nombre 
table.columns.get_loc('nombre') #2
listaNombres = list(table.iloc[:, 2])
#display(listaNombres)
# for i in range(0, 889):
#     print(i)
#     display(table2.iloc[i, 19])
#     if(not(np.isnan(table2.iloc[i, 19]))):
#         listaNombres.append(table2.iloc[i, 19])
#     else:
#         listaNombres.append(table2.iloc[i, 0])
#display(listaNombres)
#display(table2.iloc[:,0])
#print(table2['nombre'].tolist())

#Agrupar por años
#lista de años
listaAnhos = range(1900, 2018)
listaAnhos = list(map(lambda x : str(x), listaAnhos))
listaColumnas = ['institucion', 'fuente', 'nombre', 'altura', 
                'latitud' , 'longitud', 'codigo_cuenca' , 'nombre_cuenca',
                'codigo_sub_cuenca', 'nombre_sub_cuenca']

#obtener nombres de las columnas
columnHeaders = list(table)

#Transformar los año-mes en año
def año(data):
    if(data[:2] == '19' or data[:2] == '20'):
        return data[:4]
    return data 
columnYears = list(map(lambda x : año(x), columnHeaders))

# %%
#asignar nuevas columnas
table3 = table
table3.columns = columnYears
table3 = table3.sort_values('latitud', ascending=False) #De norte a sur
#display(table3)
#display(table3)
#table 3[]anos = group by
table4 = table3[['codigo_estacion',
                'zona']]


# agrupar por columna de años
auxgb = table3[listaAnhos].groupby(level=0, axis=1).mean()

#display(auxgb.loc['2010'])

for año in listaAnhos:
    table4[año] = auxgb[año]
table4['2018'] = table3['2018']    
#display(table4)

#display(table4)
#table2016Sub = table2016.head(30)
#table2016Sub.plot(kind='bar')
#table2016.plot()
#display(table2016)
#table2016.plot(kind='bar')
#Grafico de barras por caracteristica
#auxgb.plot.bar()

table5 = pd.melt(table4, id_vars=["codigo_estacion", "zona"], 
                    var_name="fecha", value_name="temperatura")


norteGrande = table5.loc[table5['zona'] == 0]
norteChico = table5.loc[table5['zona'] == 1]
central = table5.loc[table5['zona'] == 2]
sur = table5.loc[table5['zona'] == 3]
austral = table5.loc[table5['zona'] == 4]
antartica = table5.loc[table5['zona'] == 5]

#fig, axes = plt.subplots(nrows=6, ncols=1)
norteGrande.plot(x='fecha', y='temperatura', title="Temperatura por fecha Norte Grande")
norteChico.plot(x='fecha', y='temperatura',  title="Temperatura por fecha Norte Chico")
central.plot(x='fecha', y='temperatura',  title="Temperatura por fecha Central")
sur.plot(x='fecha', y='temperatura',  title="Temperatura por fecha Sur")
austral.plot(x='fecha', y='temperatura',  title="Temperatura por fecha Austral")
antartica.plot(x='fecha', y='temperatura',  title="Temperatura por fecha Antartica")


# norteChico = pd.melt(norteChico, id_vars=["codigo_estacion", "zona"], 
#                     var_name="fecha", value_name="temperatura")
# norteChico['fecha'] = norteChico['fecha'].apply(pd.to_numeric, errors='coerce')
# display(norteChico)
# #table5 = norteChico[['2010', '2011', '2012', '2013', '2014']]

# norteChico.plot.scatter(x='fecha', y='temperatura')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Cool plot test
# fig, ax = plt.subplots(1, 1, figsize=(14, 5))
# #table(ax, norteChico.describe(),loc='upper right', colWidths=[0.2, 0.2, 0.2])
# norteChico.plot(ax=ax, x='fecha', y='temperatura',  title="Temperatura por fecha Norte Chico")
# import pandas.tools.plotting as plotting
# plotting.table(ax, np.round(norteChico.describe(), 2),
#                loc='upper right', colWidths=[0.2, 0.2, 0.2])
# plt.show()
import pandas.plotting as plotting
fig = plt.figure(figsize=(8,5))

ax1 = fig.add_subplot(121)
norteChico.plot(ax=ax1, x='fecha', y='temperatura',  title="Temperatura por fecha Norte Chico")

ax2 = fig.add_subplot(122)
font_size=20
#bbox=[0, 0, 1, 1]
ax2.axis('off')
description = norteChico.describe()
plotting.table(ax2, description).auto_set_font_size(False).set_fontsize(font_size)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-fd1457dbe513> in <module>()
#      18 ax2.axis('off')
#      19 description = norteChico.describe()
# ---> 20 plotting.table(ax2, description).auto_set_font_size(False).set_fontsize(font_size)
#      21 plt.show()
#
# AttributeError: 'NoneType' object has no attribute 'set_fontsize'

# %%
#Contar nans por año
nantable = table.isnull().sum()
indexes = nantable.index
indexes = list(map(lambda x : año(x), indexes))

nantable2 = nantable
nantable2.index = indexes

nantable2 = nantable2.groupby(nantable2.index).sum()
display(nantable2[:119])
nantable2.plot()
# Out:
# 1900    10668
# 1901    10668
# 1902    10668
# 1903    10668
# 1904    10668
# 1905    10668
# 1906    10668
# 1907    10668
# 1908    10668
# 1909    10668
# 1910    10668
# 1911    10668
# 1912    10668
# 1913    10668
# 1914    10668
# 1915    10668
# 1916    10668
# 1917    10668
# 1918    10668
# 1919    10668
# 1920    10668
# 1921    10668
# 1922    10668
# 1923    10668
# 1924    10668
# 1925    10668
# 1926    10668
# 1927    10668
# 1928    10668
# 1929    10668
#         ...
# 1989     6550
# 1990     6620
# 1991     6329
# 1992     6341
# 1993     6066
# 1994     6925
# 1995     6932
# 1996     6827
# 1997     6818
# 1998     7155
# 1999     6977
# 2000     6762
# 2001     6722
# 2002     6818
# 2003     6801
# 2004     6768
# 2005     6517
# 2006     6772
# 2007     6430
# 2008     6574
# 2009     6508
# 2010     6208
# 2011     6138
# 2012     5384
# 2013     5317
# 2014     5130
# 2015     5118
# 2016     4941
# 2017     4989
# 2018      417
# ...

# %%
from matplotlib.animation import FuncAnimation
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.set_xlim(0, 900)
ax.set_ylim(-80, 40)

# create empty plot for the update function to manipulate
plot = ax.quiver([], [], [], [], [], cmap='jet', headlength=3)

display(table3)


    
# def update(i):
#     # get next thing in the iterator
#     key, data = next(iterator)
#     # set new x, y coordinates for the plot
#     plot.set_offsets(np.column_stack([data.QuivXLoc, data.QuivYLoc]))
#     # update vector and color values
#     plot.set_UVC(data.QuivXVal, data.QuivYVa-+l, data.QuivColorVal)

# # create the animation, update every 1000 ms
# ani = FuncAnimation(fig, update, interval=1000)

# # show it
# plt.show()

# %%
# c = table['1995-07']
# ax = c.plot.hist(use_index=True)
# plt.text(0.75, 0.95, f"nulls = {c.isnull().sum()}", transform=ax.transAxes, fontsize=14,
#          verticalalignment='top')
# plt.show()



display(table)
# Out:
# codigo_estacion institucion    fuente                                 nombre  \
# 1000005                 DGA   dga_web                                Visviri
# 1201005                 DGA   dga_web            Rio Caracarani En Humapalca
# 1001005                 DGA   dga_web                                Caquena
# 1202009                 DGA   dga_web                                Pacollo
# 1202012                 DGA   dga_web                            Putre (Dcp)
# 1202010                 DGA   dga_web                                  Putre
# 1020017                 DGA   dga_web                   Parinacota Ex Endesa
# 1010010                 DGA   dga_web                         Chungara Ajata
# 1300004                 DGA   dga_web                             Murmuntane
# 1211006                 DGA   dga_web                                  Lluta
# 1310018                 DGA   dga_web                          Arica Oficina
# ...

# %% [markdown]
# ### Plot norte grande

# %%
#Plot numero de nans por año
norteGrandeNT = table3.loc[table3['zona'] == 0]
norteGrandeNT = norteGrandeNT.isnull().sum()
norteGrandeNT = norteGrandeNT.groupby(norteGrandeNT.index).sum()
norteGrandeNT.plot(title="nans por año Norte Grande")

#Plot temperatura por fecha
norteGrande.plot(x='fecha', y='temperatura', title="Temperatura por fecha Norte Grande")

#Descripcion del dataframe
display(norteGrande.describe())
# Out:
#        codigo_estacion     zona  temperatura
# count     50694.000000  50694.0  9523.000000
# mean        768.903756      0.0    22.712495
# std        1178.815778      0.0     5.769360
# min       -1000.000000      0.0    -2.121444
# 25%          68.000000      0.0    20.045417
# 50%         259.000000      0.0    24.394083
# 75%         828.000000      0.0    27.023250
# max        4585.000000      0.0    33.973000

# %% [markdown]
# ### plot norte chico

# %%
#Plot numero de nans por año
norteChicoNT = table3.loc[table3['zona'] == 1]
norteChicoNT = norteChicoNT.isnull().sum()
norteChicoNT = norteChicoNT.groupby(norteChicoNT.index).sum()
norteChicoNT.plot(title="nans por año Norte Chico")

#Plot temperatura por fecha
norteChico.plot(x='fecha', y='temperatura', title="Temperatura por fecha Norte Chico")

#Descripcion del dataframe
display(norteChico.describe())
# Out:
#        codigo_estacion     zona  temperatura
# count     10591.000000  10591.0  1868.000000
# mean        719.719101      1.0    18.086781
# std         796.651117      0.0     3.520909
# min           0.000000      1.0    -0.534857
# 25%         134.000000      1.0    16.888188
# 50%         460.000000      1.0    18.506549
# 75%        1000.000000      1.0    20.075854
# max        4000.000000      1.0    28.409000

# %% [markdown]
# ### plot central

# %%
#Plot numero de nans por año
centralNT = table3.loc[table3['zona'] == 2]
centralNT = centralNT.isnull().sum()
centralNT = centralNT.groupby(centralNT.index).sum()
centralNT.plot(title="nans por año central")

#Plot temperatura por fecha
central.plot(x='fecha', y='temperatura', title="Temperatura por fecha central")

#Descripcion del dataframe
display(central.describe())
# Out:
#        codigo_estacion     zona  temperatura
# count     17017.000000  17017.0  2956.000000
# mean        649.188811      2.0    15.267807
# std         762.531210      0.0     2.978362
# min           5.000000      2.0    -1.369167
# 25%         110.000000      2.0    13.702688
# 50%         420.000000      2.0    15.376833
# 75%         850.000000      2.0    17.059542
# max        3850.000000      2.0    27.815000

# %% [markdown]
# ### plot sur

# %%
#Plot numero de nans por año
surNT = table3.loc[table3['zona'] == 3]
surNT = surNT.isnull().sum()
surNT = surNT.groupby(surNT.index).sum()
surNT.plot(title="nans por año sur")

#Plot temperatura por fecha
sur.plot(x='fecha', y='temperatura', title="Temperatura por fecha sur")

#Descripcion del dataframe
display(sur.describe())
# Out:
#        codigo_estacion    zona  temperatura
# count      5593.000000  5593.0  1149.000000
# mean        250.978723     3.0    12.124984
# std         297.552677     0.0     2.735148
# min           5.000000     3.0     6.096143
# 25%          43.000000     3.0    10.114917
# 50%          92.000000     3.0    11.567167
# 75%         345.000000     3.0    14.296167
# max         950.000000     3.0    25.067000

# %% [markdown]
# ### plot austral

# %%
#Plot numero de nans por año
australNT = table3.loc[table3['zona'] == 3]
australNT = australNT.isnull().sum()
australNT = australNT.groupby(australNT.index).sum()
australNT.plot(title="nans por año austral")

#Plot temperatura por fecha
austral.plot(x='fecha', y='temperatura', title="Temperatura por fecha austral")

#Descripcion del dataframe
display(austral.describe())
# Out:
#        codigo_estacion     zona  temperatura
# count     10948.000000  10948.0  1702.000000
# mean        149.804348      4.0     7.630257
# std         169.255185      0.0     2.998960
# min           2.000000      4.0   -10.848750
# 25%          17.250000      4.0     5.828812
# 50%          63.500000      4.0     7.117553
# 75%         242.750000      4.0     9.330771
# max         730.000000      4.0    21.228500

# %% [markdown]
# ### plot antartica

# %%
#Plot numero de nans por año
antarticaNT = table3.loc[table3['zona'] == 3]
antarticaNT = antarticaNT.isnull().sum()
antarticaNT = antarticaNT.groupby(antarticaNT.index).sum()
antarticaNT.plot(title="nans por año austral")

#Plot temperatura por fecha
antartica.plot(x='fecha', y='temperatura', title="Temperatura por fecha antartica")

#Descripcion del dataframe
display(antartica.describe())
# Out:
#        codigo_estacion     zona  temperatura
# count     10948.000000  10948.0  2097.000000
# mean        655.597826      5.0   -15.626563
# std        1093.808047      0.0    13.725262
# min       -1000.000000      5.0   -61.135143
# 25%          24.000000      5.0   -20.927917
# 50%          72.000000      5.0   -11.559000
# 75%         842.750000      5.0    -4.655833
# max        4084.000000      5.0     2.730000
